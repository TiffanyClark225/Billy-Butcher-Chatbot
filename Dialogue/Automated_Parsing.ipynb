# %% [markdown]
# # Trying different things to parse the scripts
# - Author: Tiffany Clark
# - Directly parse from wiki but they only have 7 scripts on their website
# - Other script websites have bots and anti-scraping. I've tried multiple things to get around it and was successful for one but I couldn't get the parsing right OR they do not list the character speaking. I cannot have a function parse if I don't know who's speaking
# - Added additional quotes and dialogue from websites and imdb to dialogue.txt

# %%
# Installs and imports
# !pip install beautifulsoup4 requests
import requests
from bs4 import BeautifulSoup
import os
import re

# %%
# Extract data directly from fandom wiki

def extract_butcher_dialogues(urls, output_file):
    """
    Extracts Billy Butcher's dialogues from a list of transcript webpages and saves all dialogues into one text file.

    Parameters:
        urls (list): List of URLs containing the episode transcripts.
        output_file (str): File path to save all dialogues.
    """
    all_dialogues = []  # List to store all dialogues

    # Parses through all URLs
    for idx, url in enumerate(urls, start=1):
        print(f"Processing URL {idx}: {url}")

        # Step 1: Fetch the webpage content
        response = requests.get(url)
        if response.status_code != 200:
            # Error message
            print(f"Failed to retrieve URL {url}. Status code: {response.status_code}")
            continue

        # Step 2: Parse the HTML content with BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Step 3: Locate the dialogue table or rows with <b> tags
        rows = soup.find_all('tr')  # Find all rows in the page
        for row in rows:
            speaker_cell = row.find(['th', 'td'])  # Look in <th> or <td> for the speaker
            dialogue_cell = row.find('td')  # Look for the dialogue in <td>

            if speaker_cell and dialogue_cell:
                speaker = speaker_cell.get_text(strip=True)
                dialogue = dialogue_cell.get_text(strip=True)

                # Match lines where the speaker is Billy Butcher
                if "Butcher" in speaker:
                    all_dialogues.append(dialogue)

    # Step 4: Save all dialogues to a single text file
    if all_dialogues:
        with open(output_file, "w", encoding="utf-8") as file:
            file.write("\n".join(all_dialogues))
        # Print the full path of the saved file
        full_path = os.path.abspath(output_file)
        print(f"Saved {len(all_dialogues)} lines from Billy Butcher to {full_path}.")
    else:
        print("No dialogues from Billy Butcher found.")

# List of URLs for different episode scripts
urls = [
    "https://the-boys.fandom.com/wiki/Transcript:Cherry",
    "https://the-boys.fandom.com/wiki/Transcript:The_Name_of_the_Game",
    "https://the-boys.fandom.com/wiki/Transcript:Season_Four_Finale",
    "https://the-boys.fandom.com/wiki/Transcript:Get_Some",
    "https://the-boys.fandom.com/wiki/Transcript:Good_for_the_Soul",
    "https://the-boys.fandom.com/wiki/Transcript:Herogasm",
    "https://the-boys.fandom.com/wiki/Transcript:The_Female_of_the_Species",
]

# Output file for all dialogues
output_file = "dialogue.txt"

# Process all URLs and save results
extract_butcher_dialogues(urls, output_file)
# Out:
# Processing URL 1: https://the-boys.fandom.com/wiki/Transcript:Cherry
# Processing URL 2: https://the-boys.fandom.com/wiki/Transcript:The_Name_of_the_Game
# Processing URL 3: https://the-boys.fandom.com/wiki/Transcript:Season_Four_Finale
# Processing URL 4: https://the-boys.fandom.com/wiki/Transcript:Get_Some
# Processing URL 5: https://the-boys.fandom.com/wiki/Transcript:Good_for_the_Soul
# Processing URL 6: https://the-boys.fandom.com/wiki/Transcript:Herogasm
# Processing URL 7: https://the-boys.fandom.com/wiki/Transcript:The_Female_of_the_Species
# Saved 137 lines from Billy Butcher to /workspaces/Billy-Butcher-Chatbot/Dialogue/dialogue.txt.

# %% [raw]
# # Code to extract dialogue from Springfield website; however, the website does not always list
# # which actor is speaking the lines, so I cannot parse all of the dialogue from Billy Butcher
# # so I'm not using this code
#
# def extract_butcher_dialogue_springfield(urls, output_directory):
#     """
#     Extracts Billy Butcher's dialogues from Springfield! Springfield! scripts
#     where dialogues are in the format "[Butcher]" and saves them into separate text files.
#
#     Parameters:
#         urls (list): List of Springfield! Springfield! URLs containing the episode scripts.
#         output_directory (str): Directory to save the text files with dialogues.
#     """
#     # Ensure the output directory exists
#     os.makedirs(output_directory, exist_ok=True)
#
#     for idx, url in enumerate(urls, start=1):
#         print(f"Processing URL {idx}: {url}")
#         try:
#             # Step 1: Fetch the webpage
#             response = requests.get(url)
#             response.raise_for_status()
#             soup = BeautifulSoup(response.text, 'html.parser')
#
#             # Step 2: Extract the script container
#             script_div = soup.find('div', class_='scrolling-script-container')
#             if not script_div:
#                 print(f"No script found in URL {url}.")
#                 continue
#
#             # Step 3: Parse character dialogues
#             butcher_dialogues = []
#             lines = script_div.get_text(separator="\n").splitlines()  # Extract text and split by line
#
#             for line in lines:
#                 # Clean up the line
#                 line = line.strip()  # Remove leading and trailing spaces
#                 if line.startswith("[Butcher]"):  # Check if the line starts with "[Butcher]"
#                     dialogue = re.sub(r"^\[Butcher\]\s*", "", line)  # Remove "[Butcher]" from the line
#                     butcher_dialogues.append(dialogue.strip())
#
#             # Step 4: Save dialogues to a text file
#             if butcher_dialogues:
#                 output_file = os.path.join(output_directory, f"BI_script{idx}.txt")
#                 with open(output_file, "w", encoding="utf-8") as file:
#                     file.write("\n".join(butcher_dialogues))
#                 print(f"Saved {len(butcher_dialogues)} lines from Billy Butcher to {output_file}.")
#             else:
#                 print(f"No dialogues from Billy Butcher found in URL {url}.")
#
#         except Exception as e:
#             print(f"Failed to process URL {url}. Error: {e}")
#
# # List of URLs for the episode scripts
# urls = [
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s03e01",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s03e02",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s03e03",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s03e06",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s03e07",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s03e08",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e02",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e03",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e04",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e05",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e06",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e07",
#     "https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=the-boys-2019&episode=s04e08",
#
#
# ]
#
# # Directory to save the output text files
# output_directory = "Butcher_Dialogues_Springfield"
#
# # Process all URLs and save results
# extract_butcher_dialogue_springfield(urls, output_directory)

# %%
# Manually found other dialogue from other websites and imdb and created a function to add these lines to the dialogue.txt

# Path to the existing dialogue file
file_path = "dialogue.txt"

# The new dialogue lines to add
new_lines = """
You're a smart lad, but you still ain't twigged to the one weakness they all got. Their reputations.
Guess this means we're breaking up...nazi bitch.
Security's tighter than a choir boy's asshole.
We should lob a fucking nuke at him, get it over and done with. You know what I'm saying?
Well, well, well. She's quite tasty up close and personal. I get what you see in her.
What have you got to lose that you ain't already lost?
Wow. Mesmer. Hello. Big Fan. Be with you in a minute.
Too fucking right. More than anything.
Well, maybe I don't want to look at you after what you done to my Becca.
Sooner or later, Homelander will find Ryan. Okay? It's just a matter of time. I have to do this, all right? You don't.
You're the one with your tail between your legs on all them fucking talk shows. And then they go and make Starlight co-captain? Tsk-tsk-tsk. That's gotta sting.
Never go into shark-infested waters without chum.
I'd call you a cunt, but you don't have the depth or the warmth?
Alright, then. Let's get a shift on.
Straight up web weaver stinky spider. Heroine enemas don't come cheap, son.
This ain't a bloody kinder care we're on about, son. Its Vought fucking Tower.
Arse cancer. shitting his guts out as we speak, one hopes.
Nice decor. 80s. Serial killer. Love it.
fuck me. I figured you was dead.
A stranger is just a friend you ain't met yet.
You turned a racist piece of shit into America's sweetheart.
All right. Good talk. Think about it. I'm here all day, all right?
I'm trying to save the world here. Claret's gonna get split.
Just what? F*ck off to Epcot? The Hamptons? Maybe pump out a few flying babies?
We're whistlin' our way towards a fucking apocalypse!
He's at 673 Nosh My Bollocks Ave. You want a pen and paper?
Listen, mate. I’m the only thing
Don't be daft. This shift is poison, Hughie. A lad like you don't want no part of it.
Contingency. In case things go ass over tit at the lab.
All right, you lot. In the safe.
Yeah. He's got a hard-on for mass murder and giving kids cancer and his big old answer to the existential clusterf*ck that is humanity is to nail his own bleeding son to a plank. That is a c*nt move. Come on, even you got to agree with me there. We should lob a f*cking nuke at him, get it over and done with. You know what I'm saying?
That cunt's gotta go.
Quit while you're behind.
Get out of here, Ryan!
Used the belt, did he?
You don't trust me. Susan, I am shocked and saddened by that.
You can't allow yourself to be distracted by another bird. Especially not a Supe.
Get out of the building! Now!
Not enough? If torturing and burning a bunch of mentals on board's say-so ain't enough for you moppets, then what the fuck are you good for, huh? A strongly worded tweet?
It don't matter. You didn't name him, didn't raise him. Vought grew him in a fucking test tube to take your place. He's the fucking reason they left you to rot with the Ivans. Look, mate...we had a deal.
You're a bunch of pathetic Supe-worshipping fucks. I bet you'd thank a Supe if they shit on your mum's best china. Did it ever occur to you that they split your spine or broke your dick just for a laugh? Where's your fucking rage?! Your self-respect?! Sitting here in your little share circle. Having a little whinge and a moan. Fuck 'letting go.' You should be out there with a fucking chain saw, going after 'em! Just a bunch of scared fucking rabbits.
The American people, they know. They know when someone's telling the facts, and they know when the media is lying to them.
Well, insanely desperate's where we are, don't you think, love?
Hey, Frenchie. Don't get caught.
If a Supe done that when she was happy, imagine what one would do if she found out you'd been lying to her from the get-go?
Oi! Evening, cunts.
You're a good cunt, Hughie.
We're sniffing down a sh*t sandwich the size of Watergate.
What are you doing here?
What's sporty spice up to?
Stand down.
What the fuck are you waiting for?
Maybe you should take a look in the mirror, mate. Cause that bitch should bother you.
For once, I've leveled the fucking playing field.
Having a good growler, are we?
You just want to kick back, drink a few Mai Tais, and let us do all the work, is that it?
You really are the spitting image of my little brother.
Look, uh.. I don't mean to be rude, but can we just skip to the part where you laser my fucking brains out?
Go on, son. Have a bump.
What a mess, you alright?
With great power comes the absolute certainty that you'll turn into a right cunt.
When you put them together, they're the goddamn fucking Spice Girls.
Give her my best.
Look, potato, f*cking po-tah-to. We're both in a sh*tload of trouble.
You cheeky little blighter.
Scorched earth.
Just remember who your friends ... and your enemies are.
Don't you worry. Daddy's home.
Because you're a ruthless b*stard.
Kid's a weeper. Don't want him to get snot on me jacket.Congress? Please. What a bunch of corrupting f*cking c*nts they are.
So it's just business then, 'ey?
Oi Cunt!
Well, you can kindly fuck off then.
Top notch show, love. Just weren't sure if you wanted us to kneel before your cross or burn it.
It's like Hughie's infected you both with a raging case of vagina.
Expecting a happy ending, were we? Well, I'm sorry, Hughie. It ain't that kind of massage parlor.
Now I ain't going to ask you to come along.
Evening, cunts. We're here to commit a bit of treason.
People love that cozy feeling that Supes give them. Some golden fuck to swoop out of the sky and save the day, so you don't got to do it yourself.
Yes, I did. I ain't gonna sugarcoat it, your football days are over.
Musta missed it.
Cool your jets, guy, it's not a hate crime.
In the safe. Let's go.
"""

try:
    # Append the new lines to the file
    with open(file_path, "a", encoding="utf-8") as file:
        file.write("\n" + new_lines.strip())  # Ensure lines are appended correctly
    print(f"Successfully added {len(new_lines.splitlines())} lines to {file_path}.")
# Error messages
except FileNotFoundError:
    print(f"Error: File not found at {file_path}.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Successfully added 154 lines to dialogue.txt.
